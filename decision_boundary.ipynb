# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_validate, train_test_split
import pandas as pd
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram
from scipy import stats
from sklearn.cluster import AgglomerativeClustering
import seaborn as sns
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
from utils import get_mouse_trial_arrays, get_mouse_stim_labels, plot_pca_decision_boundary

# %%
# Load the .mat file
mat_file = scipy.io.loadmat('general/full_data.mat')
mouse_ids = scipy.io.loadmat('general/Mouse_IDS.mat')['mouse_id']

# %%
mouse_trial_arrays = get_mouse_trial_arrays(mat_file, mouse_ids)
mouse_stim_labels = get_mouse_stim_labels(mat_file, mouse_ids)

# %%
color_map = {0: '#1f77b4', 1: 'grey', 3: 'red', 4: '#9467bd'}

# %% [markdown]
# # Aversive vs Noxious

# %%
mouse_id = 1

plot_pca_decision_boundary(mouse_stim_labels[mouse_id], mouse_trial_arrays[mouse_id], stim_condition1=0, stim_condition2=3, stim_label1='Aversive', stim_label2='Noxious', color_map=color_map)
plt.ylim(-200, 200)
# Out:
# Classification score:  1.0
# (-200.0, 200.0)

# %%
mouse_id = 2

plot_pca_decision_boundary(mouse_stim_labels[mouse_id], mouse_trial_arrays[mouse_id], stim_condition1=0, stim_condition2=3, stim_label1='Aversive', stim_label2='Noxious', color_map=color_map)
# Out:
# Classification score:  1.0

# %%
mouse_id = 3

plot_pca_decision_boundary(mouse_stim_labels[mouse_id], mouse_trial_arrays[mouse_id], stim_condition1=0, stim_condition2=3, stim_label1='Aversive', stim_label2='Noxious', color_map=color_map)
plt.ylim(-200, 200)
# Out:
# Classification score:  1.0
# (-200.0, 200.0)

# %% [markdown]
# # Aversive vs reward

# %%
mouse_id = 1
plot_pca_decision_boundary(mouse_stim_labels[mouse_id], mouse_trial_arrays[mouse_id], stim_condition1=0, stim_condition2=4, stim_label1='Aversive', stim_label2='Reward', color_map=color_map)
# Out:
# Classification score:  1.0

# %%
mouse_id = 2
plot_pca_decision_boundary(mouse_stim_labels[mouse_id], mouse_trial_arrays[mouse_id], stim_condition1=0, stim_condition2=4, stim_label1='Aversive', stim_label2='Reward', color_map=color_map)
plt.ylim(-200, 200)
# Out:
# Classification score:  1.0
# (-200.0, 200.0)

# %%
mouse_id = 3
plot_pca_decision_boundary(mouse_stim_labels[mouse_id], mouse_trial_arrays[mouse_id], stim_condition1=0, stim_condition2=4, stim_label1='Aversive', stim_label2='Reward', color_map=color_map)
# Out:
# Classification score:  1.0

# %% [markdown]
# # Aversive vs Control

# %%
mouse_id = 1
plot_pca_decision_boundary(mouse_stim_labels[mouse_id], mouse_trial_arrays[mouse_id], stim_condition1=0, stim_condition2=1, stim_label1='Aversive', stim_label2='Control', color_map=color_map)
plt.ylim(-200, 200)
# Out:
# Classification score:  1.0
# (-200.0, 200.0)

# %%
mouse_id = 2
plot_pca_decision_boundary(mouse_stim_labels[mouse_id], mouse_trial_arrays[mouse_id], stim_condition1=0, stim_condition2=1, stim_label1='Aversive', stim_label2='Control', color_map=color_map)
# Out:
# Classification score:  1.0

# %%
mouse_id = 3
plot_pca_decision_boundary(mouse_stim_labels[mouse_id], mouse_trial_arrays[mouse_id], stim_condition1=0, stim_condition2=1, stim_label1='Aversive', stim_label2='Control', color_map=color_map)
plt.ylim(-100, 120)
# Out:
# Classification score:  0.5
# (-100.0, 120.0)
